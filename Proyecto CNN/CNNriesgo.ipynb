# %%
import numpy as np
import os
import re
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
import keras
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from keras.models import Sequential,Model
from tensorflow.keras.layers import Input
from keras.layers import Dense, Dropout, Flatten
from tensorflow.keras.layers import (
    BatchNormalization, SeparableConv2D, MaxPooling2D, Activation, Flatten, Dropout, Dense, Conv2D
)
from keras.layers import LeakyReLU

# %%
dirname = os.path.join(os.getcwd(),'C:\\devs\\datasets\\dataset50rotadofiltros2')
imgpath = dirname + os.sep 

images = []
directories = []
dircount = []
prevRoot=''
cant=0

print("leyendo imagenes de ",imgpath)

for root, dirnames, filenames in os.walk(imgpath):
    for filename in filenames:
        if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
            cant=cant+1
            filepath = os.path.join(root, filename)
            image = plt.imread(filepath)
            if(len(image.shape)==3):
                
                images.append(image)
            b = "Leyendo..." + str(cant)
            print (b, end="\r")
            if prevRoot !=root:
                print(root, cant)
                prevRoot=root
                directories.append(root)
                dircount.append(cant)
                cant=0
dircount.append(cant)

dircount = dircount[1:]
dircount[0]=dircount[0]+1
print('Directorios leidos:',len(directories))
print("Imagenes en cada directorio", dircount)
print('suma Total de imagenes en subdirs:',sum(dircount))
# Out:
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# <>:14: SyntaxWarning: invalid escape sequence '\.'
# C:\Users\ferco\AppData\Local\Temp\ipykernel_99276\2379502295.py:14: SyntaxWarning: invalid escape sequence '\.'
#   if re.search("\.(jpg|jpeg|png|bmp|tiff)$", filename):
# leyendo imagenes de  C:\devs\datasets\dataset50rotadofiltros2\
# C:\devs\datasets\dataset50rotadofiltros2\ferrari 1
# C:\devs\datasets\dataset50rotadofiltros2\hummer 11320
# C:\devs\datasets\dataset50rotadofiltros2\mclaren 11440
# C:\devs\datasets\dataset50rotadofiltros2\porsche 11200
# C:\devs\datasets\dataset50rotadofiltros2\vocho 11440
# Directorios leidos: 5
# Imagenes en cada directorio [11321, 11440, 11200, 11440, 11239]
# suma Total de imagenes en subdirs: 56640

# %%
labels=[]
indice=0
for cantidad in dircount:
    for i in range(cantidad):
        labels.append(indice)
    indice=indice+1
print("Etiquetas creadas: ",len(labels))
# Out:
# Etiquetas creadas:  56640

# %%
cars=[]
indice=0
for directorio in directories:
    name = directorio.split(os.sep)
    print(indice , name[len(name)-1])
    cars.append(name[len(name)-1])
    indice=indice+1
# Out:
# 0 ferrari
# 1 hummer
# 2 mclaren
# 3 porsche
# 4 vocho

# %%
y = np.array(labels)
X = np.array(images, dtype=np.uint8)

classes = np.unique(y)
nClasses = len(classes)
print('Total number of outputs : ', nClasses)
print('Output classes : ', classes)
# Out:
# Total number of outputs :  5
# Output classes :  [0 1 2 3 4]

# %%
train_X,test_X,train_Y,test_Y = train_test_split(X,y,test_size=0.2)
print('Training data shape : ', train_X.shape, train_Y.shape)
print('Testing data shape : ', test_X.shape, test_Y.shape)
# Out:
# Training data shape :  (45312, 50, 50, 3) (45312,)
# Testing data shape :  (11328, 50, 50, 3) (11328,)

# %%
plt.figure(figsize=[5,5])

plt.subplot(121)
plt.imshow(train_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(train_Y[0]))

plt.subplot(122)
plt.imshow(test_X[0,:,:], cmap='gray')
plt.title("Ground Truth : {}".format(test_Y[0]))
# Out:
# Text(0.5, 1.0, 'Ground Truth : 3')

# %%
train_X = train_X.astype('float32')
test_X = test_X.astype('float32')
train_X = train_X/255.
test_X = test_X/255.
plt.imshow(test_X[0,:,:])

# %%
train_Y_one_hot = to_categorical(train_Y)
test_Y_one_hot = to_categorical(test_Y)

print('Original label:', train_Y[0])
print('After conversion to one-hot:', train_Y_one_hot[0])
# Out:
# Original label: 0
# After conversion to one-hot: [1. 0. 0. 0. 0.]

# %%
#Mezclar todo y crear los grupos de entrenamiento y testing
train_X,valid_X,train_label,valid_label = train_test_split(train_X, train_Y_one_hot, test_size=0.2, random_state=13)
print(train_X.shape,valid_X.shape,train_label.shape,valid_label.shape)
# Out:
# (36249, 50, 50, 3) (9063, 50, 50, 3) (36249, 5) (9063, 5)

# %%
#declaramos variables con los parámetros de configuración de la red
INIT_LR = 5e-3 # Valor inicial de learning rate. El valor 1e-3 corresponde con 0.001
epochs = 50 # Cantidad de iteraciones completas al conjunto de imagenes de entrenamiento
batch_size = 64 # cantidad de imágenes que se toman a la vez en memoria

# %%
car_model = Sequential()
car_model.add(Input(shape=(50, 50, 3)))
car_model.add(Conv2D(32, kernel_size=(3, 3), activation='linear', padding='same'))
car_model.add(LeakyReLU(negative_slope=0.1))
car_model.add(MaxPooling2D((2, 2), padding='same'))
car_model.add(Dropout(0.25))

car_model.add(Conv2D(64, kernel_size=(3, 3), activation='linear', padding='same'))
car_model.add(LeakyReLU(negative_slope=0.1))
car_model.add(MaxPooling2D((2, 2), padding='same'))
car_model.add(Dropout(0.25))

car_model.add(Flatten())
car_model.add(Dense(128, activation='linear'))
car_model.add(LeakyReLU(negative_slope=0.1))
car_model.add(Dropout(0.25))

car_model.add(Dense(nClasses, activation='softmax'))

# %%
car_model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d_6 (Conv2D)                    │ (None, 50, 50, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_9 (LeakyReLU)            │ (None, 50, 50, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_6 (MaxPooling2D)       │ (None, 25, 25, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_9 (Dropout)                  │ (None, 25, 25, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_7 (Conv2D)                    │ (None, 25, 25, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_10 (LeakyReLU)           │ (None, 25, 25, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_7 (MaxPooling2D)       │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_10 (Dropout)                 │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_3 (Flatten)                  │ (None, 10816)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 128)                 │       1,384,576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ leaky_re_lu_11 (LeakyReLU)           │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 5)                   │             645 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,404,613 (5.36 MB)
#  Trainable params: 1,404,613 (5.36 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
car_model.compile(
    loss=keras.losses.categorical_crossentropy, 
    optimizer=tf.keras.optimizers.SGD(learning_rate=INIT_LR, decay=INIT_LR / 100),
    metrics=['accuracy']
)
# Out:
# C:\Users\ferco\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\optimizers\base_optimizer.py:86: UserWarning: Argument `decay` is no longer supported and will be ignored.
#   warnings.warn(

# %%
# este paso puede tomar varios minutos, dependiendo de tu ordenador, cpu y memoria ram libre
# Entrenamiento del modelo
car_train = car_model.fit(
    train_X, 
    train_label, 
    batch_size=batch_size, 
    epochs=epochs, 
    verbose=1, 
    validation_data=(valid_X, valid_label)
)
# Out:
# Epoch 1/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 32s 54ms/step - accuracy: 0.2408 - loss: 1.5958 - val_accuracy: 0.3459 - val_loss: 1.5490
# Epoch 2/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 28s 49ms/step - accuracy: 0.3262 - loss: 1.5346 - val_accuracy: 0.3752 - val_loss: 1.4962
# Epoch 3/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 27s 48ms/step - accuracy: 0.3661 - loss: 1.4843 - val_accuracy: 0.4021 - val_loss: 1.4466
# Epoch 4/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 24s 42ms/step - accuracy: 0.3951 - loss: 1.4296 - val_accuracy: 0.4385 - val_loss: 1.3910
# Epoch 5/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 24s 42ms/step - accuracy: 0.4265 - loss: 1.3829 - val_accuracy: 0.4499 - val_loss: 1.3619
# Epoch 6/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.4493 - loss: 1.3512 - val_accuracy: 0.4606 - val_loss: 1.3141
# Epoch 7/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - accuracy: 0.4678 - loss: 1.3079 - val_accuracy: 0.5077 - val_loss: 1.2643
# Epoch 8/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.4788 - loss: 1.2834 - val_accuracy: 0.5194 - val_loss: 1.2261
# Epoch 9/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 24s 42ms/step - accuracy: 0.4932 - loss: 1.2623 - val_accuracy: 0.5289 - val_loss: 1.1934
# Epoch 10/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.5045 - loss: 1.2262 - val_accuracy: 0.4912 - val_loss: 1.2541
# Epoch 11/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - accuracy: 0.5202 - loss: 1.1999 - val_accuracy: 0.5643 - val_loss: 1.1466
# Epoch 12/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.5339 - loss: 1.1727 - val_accuracy: 0.5623 - val_loss: 1.1510
# Epoch 13/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 25s 43ms/step - accuracy: 0.5479 - loss: 1.1455 - val_accuracy: 0.5691 - val_loss: 1.0982
# Epoch 14/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 41s 44ms/step - accuracy: 0.5655 - loss: 1.1154 - val_accuracy: 0.5830 - val_loss: 1.0692
# Epoch 15/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 25s 43ms/step - accuracy: 0.5731 - loss: 1.0886 - val_accuracy: 0.5945 - val_loss: 1.0439
# Epoch 16/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.5843 - loss: 1.0671 - val_accuracy: 0.6250 - val_loss: 0.9972
# Epoch 17/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 25s 43ms/step - accuracy: 0.6020 - loss: 1.0340 - val_accuracy: 0.6183 - val_loss: 0.9919
# Epoch 18/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 25s 44ms/step - accuracy: 0.6129 - loss: 1.0079 - val_accuracy: 0.6489 - val_loss: 0.9435
# Epoch 19/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 24s 43ms/step - accuracy: 0.6253 - loss: 0.9805 - val_accuracy: 0.6551 - val_loss: 0.9281
# Epoch 20/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 22s 38ms/step - accuracy: 0.6392 - loss: 0.9518 - val_accuracy: 0.6497 - val_loss: 0.9229
# Epoch 21/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.6461 - loss: 0.9358 - val_accuracy: 0.6961 - val_loss: 0.8563
# Epoch 22/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.6624 - loss: 0.9017 - val_accuracy: 0.6983 - val_loss: 0.8470
# Epoch 23/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.6702 - loss: 0.8786 - val_accuracy: 0.7189 - val_loss: 0.8003
# Epoch 24/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.6826 - loss: 0.8515 - val_accuracy: 0.7234 - val_loss: 0.7895
# Epoch 25/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.6935 - loss: 0.8309 - val_accuracy: 0.7115 - val_loss: 0.7970
# Epoch 26/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7049 - loss: 0.8025 - val_accuracy: 0.7374 - val_loss: 0.7514
# Epoch 27/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7086 - loss: 0.7834 - val_accuracy: 0.7539 - val_loss: 0.7074
# Epoch 28/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7244 - loss: 0.7582 - val_accuracy: 0.7558 - val_loss: 0.7056
# Epoch 29/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7241 - loss: 0.7432 - val_accuracy: 0.7642 - val_loss: 0.6690
# Epoch 30/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7358 - loss: 0.7223 - val_accuracy: 0.7627 - val_loss: 0.6702
# Epoch 31/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.7385 - loss: 0.7102 - val_accuracy: 0.7773 - val_loss: 0.6397
# Epoch 32/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 22s 39ms/step - accuracy: 0.7542 - loss: 0.6838 - val_accuracy: 0.7849 - val_loss: 0.6175
# Epoch 33/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 22s 38ms/step - accuracy: 0.7686 - loss: 0.6451 - val_accuracy: 0.7906 - val_loss: 0.5968
# Epoch 34/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7695 - loss: 0.6386 - val_accuracy: 0.7851 - val_loss: 0.6209
# Epoch 35/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7689 - loss: 0.6260 - val_accuracy: 0.7893 - val_loss: 0.6125
# Epoch 36/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7812 - loss: 0.6073 - val_accuracy: 0.7955 - val_loss: 0.5666
# Epoch 37/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7850 - loss: 0.5875 - val_accuracy: 0.8140 - val_loss: 0.5382
# Epoch 38/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7918 - loss: 0.5739 - val_accuracy: 0.7929 - val_loss: 0.5954
# Epoch 39/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.7990 - loss: 0.5591 - val_accuracy: 0.8235 - val_loss: 0.5056
# Epoch 40/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8086 - loss: 0.5326 - val_accuracy: 0.8264 - val_loss: 0.5106
# Epoch 41/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8109 - loss: 0.5287 - val_accuracy: 0.8430 - val_loss: 0.4680
# Epoch 42/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8140 - loss: 0.5162 - val_accuracy: 0.8380 - val_loss: 0.4615
# Epoch 43/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8213 - loss: 0.5004 - val_accuracy: 0.8463 - val_loss: 0.4428
# Epoch 44/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8277 - loss: 0.4840 - val_accuracy: 0.8557 - val_loss: 0.4171
# Epoch 45/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8263 - loss: 0.4775 - val_accuracy: 0.8485 - val_loss: 0.4390
# Epoch 46/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 38ms/step - accuracy: 0.8373 - loss: 0.4542 - val_accuracy: 0.8692 - val_loss: 0.3917
# Epoch 47/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8447 - loss: 0.4439 - val_accuracy: 0.8564 - val_loss: 0.4142
# Epoch 48/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8475 - loss: 0.4275 - val_accuracy: 0.8594 - val_loss: 0.4067
# Epoch 49/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8526 - loss: 0.4134 - val_accuracy: 0.8717 - val_loss: 0.3793
# Epoch 50/50
# 567/567 ━━━━━━━━━━━━━━━━━━━━ 21s 37ms/step - accuracy: 0.8598 - loss: 0.3991 - val_accuracy: 0.8832 - val_loss: 0.3551

# %%
# guardamos la red, para reutilizarla en el futuro, sin tener que volver a entrenar
car_model.save("C:\\devs\\IAProyects\\Proyecto CNN\\autos_modelos50x50mejorado3.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
test_eval = car_model.evaluate(test_X, test_Y_one_hot, verbose=1)
# Out:
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8789 - loss: 0.3630

# %%
print('Test loss:', test_eval[0])
print('Test accuracy:', test_eval[1])
# Out:
# Test loss: 0.362973690032959
# Test accuracy: 0.8787076473236084

# %%
car_train.history
# Out:
# {'accuracy': [0.2691384553909302,
#   0.3358161747455597,
#   0.37076884508132935,
#   0.40003862977027893,
#   0.4317084550857544,
#   0.45115727186203003,
#   0.46922674775123596,
#   0.48415127396583557,
#   0.5009241700172424,
#   0.5106347799301147,
#   0.5263041853904724,
#   0.5393252372741699,
#   0.5508289933204651,
#   0.5668018460273743,
#   0.5780573487281799,
#   0.5901404023170471,
#   0.6071891784667969,
#   0.6175894737243652,
#   0.6278793811798096,
#   0.6442936062812805,
#   0.6503075957298279,
#   0.6638528108596802,
#   0.6739495992660522,
#   0.6817843317985535,
#   0.6939501762390137,
#   0.7046263217926025,
#   0.7114403247833252,
#   0.725233793258667,
#   0.7289028763771057,
#   0.73866868019104,
#   0.7447929382324219,
#   0.7539242506027222,
#   0.7619244456291199,
#   0.7667521834373474,
#   0.7726281881332397,
#   0.781097412109375,
#   0.7865044474601746,
#   0.7930425405502319,
#   0.8015945553779602,
#   0.8066429495811462,
#   0.8120499849319458,
#   0.8162156343460083,
#   0.8225606083869934,
#   0.8277193903923035,
#   0.8305332660675049,
#   0.8374024033546448,
#   0.8434163928031921,
#   0.8485751152038574,
#   0.8535407781600952,
#   0.8571270704269409],
#  'loss': [1.579374074935913,
#   1.5240073204040527,
#   1.4731559753417969,
#   1.4207487106323242,
#   1.3738492727279663,
#   1.33931303024292,
#   1.304545521736145,
#   1.273132562637329,
#   1.2455774545669556,
#   1.216765284538269,
#   1.1902194023132324,
#   1.1629202365875244,
#   1.1403827667236328,
#   1.109845757484436,
#   1.0850189924240112,
#   1.0565643310546875,
#   1.0273427963256836,
#   1.0018223524093628,
#   0.9771943092346191,
#   0.9470470547676086,
#   0.929078996181488,
#   0.898756742477417,
#   0.8743342757225037,
#   0.8514050841331482,
#   0.8281988501548767,
#   0.8022787570953369,
#   0.781523585319519,
#   0.7567091584205627,
#   0.735527515411377,
#   0.7157448530197144,
#   0.6965553760528564,
#   0.6799251437187195,
#   0.6567451357841492,
#   0.6395602822303772,
#   0.6241262555122375,
#   0.6070713400840759,
#   0.5855528712272644,
#   0.5682165622711182,
#   0.5552867650985718,
#   0.5410987138748169,
#   0.5250883102416992,
#   0.5104062557220459,
#   0.49656057357788086,
#   0.48248034715652466,
#   0.4670531749725342,
#   0.45291927456855774,
#   0.44325053691864014,
#   0.4251532554626465,
#   0.4128192365169525,
#   0.40288278460502625],
#  'val_accuracy': [0.3459119498729706,
#   0.37515172362327576,
#   0.4020743668079376,
#   0.43848615884780884,
#   0.44985103607177734,
#   0.460553914308548,
#   0.5076685547828674,
#   0.5193644762039185,
#   0.5288535952568054,
#   0.4912280738353729,
#   0.5642723441123962,
#   0.5622861981391907,
#   0.5691272020339966,
#   0.5830299258232117,
#   0.5945051312446594,
#   0.6249586343765259,
#   0.6183382868766785,
#   0.6489021182060242,
#   0.6550810933113098,
#   0.6496744751930237,
#   0.6961271166801453,
#   0.6983338594436646,
#   0.7188568711280823,
#   0.7233808040618896,
#   0.7114641666412354,
#   0.7373937964439392,
#   0.7539446353912354,
#   0.7558203935623169,
#   0.7642061114311218,
#   0.7626613974571228,
#   0.7773364186286926,
#   0.784949779510498,
#   0.7905770540237427,
#   0.7850601077079773,
#   0.7892529964447021,
#   0.795542299747467,
#   0.8139688968658447,
#   0.792894184589386,
#   0.8234580159187317,
#   0.8264371752738953,
#   0.8429879546165466,
#   0.8380227088928223,
#   0.8462981581687927,
#   0.8556769490242004,
#   0.848504900932312,
#   0.8692485690116882,
#   0.8564493060112,
#   0.8594284653663635,
#   0.8716760277748108,
#   0.8831512928009033],
#  'val_loss': [1.549001932144165,
#   1.4961581230163574,
#   1.4465848207473755,
#   1.391029715538025,
#   1.3619009256362915,
#   1.3140842914581299,
#   1.2642742395401,
#   1.226057767868042,
#   1.193424940109253,
#   1.2541158199310303,
#   1.1465696096420288,
#   1.1509853601455688,
#   1.0982308387756348,
#   1.069175362586975,
#   1.0439019203186035,
#   0.9971903562545776,
#   0.9918674826622009,
#   0.9435215592384338,
#   0.9280829429626465,
#   0.922931432723999,
#   0.8562930822372437,
#   0.8470404148101807,
#   0.8002895712852478,
#   0.7894837856292725,
#   0.7969909310340881,
#   0.7513934373855591,
#   0.7073813676834106,
#   0.7055743336677551,
#   0.6690341830253601,
#   0.6701673865318298,
#   0.6396852135658264,
#   0.6174730062484741,
#   0.5968133807182312,
#   0.6208764314651489,
#   0.612531304359436,
#   0.5666407346725464,
#   0.5381659865379333,
#   0.5954133868217468,
#   0.5056495070457458,
#   0.5106301307678223,
#   0.46802547574043274,
#   0.4615294933319092,
#   0.44281384348869324,
#   0.41708528995513916,
#   0.4390135705471039,
#   0.39173707365989685,
#   0.41421863436698914,
#   0.40671974420547485,
#   0.3793140947818756,
#   0.35514116287231445]}

# %%
accuracy = car_train.history['accuracy']
val_accuracy = car_train.history['val_accuracy']
loss = car_train.history['loss']
val_loss = car_train.history['val_loss']
epochs = range(len(accuracy))
plt.plot(epochs, accuracy, 'bo', label='Training accuracy')
plt.plot(epochs, val_accuracy, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
predicted_classes2 = car_model.predict(test_X)
# Out:
# 354/354 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step

# %%
predicted_classes=[]
for predicted_car in predicted_classes2:
    predicted_classes.append(predicted_car.tolist().index(max(predicted_car)))
predicted_classes=np.array(predicted_classes)

# %%
predicted_classes.shape, test_Y.shape
# Out:
# ((11328,), (11328,))

# %%
correct = np.where(predicted_classes == test_Y)[0]
print("Found %d correct labels" % len(correct))
for i, correct in enumerate(correct[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[correct].reshape(50, 50, 3), interpolation='none')
    plt.title("{}, {}".format(cars[predicted_classes[correct]],
                                                   cars[test_Y[correct]]))

    plt.tight_layout()
plt.show()
# Out:
# Found 9954 correct labels

# %%
incorrect = np.where(predicted_classes!=test_Y)[0]
print("Found %d incorrect labels" % len(incorrect))
for i, incorrect in enumerate(incorrect[0:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(test_X[incorrect].reshape(50,50,3), cmap='gray', interpolation='none')
    plt.title("{}, {}".format(cars[predicted_classes[incorrect]],
                                                    cars[test_Y[incorrect]]))
    plt.tight_layout()
# Out:
# Found 1374 incorrect labels

# %%
target_names = ["Class {}".format(i) for i in range(nClasses)]
print(classification_report(test_Y, predicted_classes, target_names=target_names))
# Out:
#               precision    recall  f1-score   support
#
#      Class 0       0.87      0.82      0.85      2321
#      Class 1       0.93      0.91      0.92      2321
#      Class 2       0.88      0.85      0.86      2192
#      Class 3       0.82      0.90      0.86      2313
#      Class 4       0.88      0.92      0.90      2181
#
#     accuracy                           0.88     11328
#    macro avg       0.88      0.88      0.88     11328
# weighted avg       0.88      0.88      0.88     11328

# %%
from skimage.transform import resize
import numpy as np
import matplotlib.pyplot as plt
import cv2 as cv

# Definir imágenes de prueba
filenames = ['C:\\devs\\IAProyects\\Proyecto CNN\\Imagenes prueba\\hummer.jpg']

# Cargar las clases de autos (asegúrate de definir correctamente "cars")
cars = ['Ferrari F40', 'Hummer', 'McLaren 720', 'Porsche 911', 'Vocho']

# Procesar las imágenes y hacer predicciones
images = []

for filepath in filenames:
    try:
        # Cargar imagen en formato RGB con OpenCV
        image = cv.imread(filepath)  # OpenCV carga en BGR por defecto
        if image is None:
            print(f"Error: No se pudo cargar la imagen {filepath}")
            continue
        
        # Convertir la imagen de BGR a RGB
        image = cv.cvtColor(image, cv.COLOR_BGR2RGB)

        # Redimensionar la imagen a 50x50 usando OpenCV
        image_resized = cv.resize(image, (50, 50))

        # Normalizar la imagen al rango [0, 1]
        image_resized = image_resized.astype('float32') / 255.0

        # Agregar la imagen procesada a la lista
        images.append(image_resized)

    except Exception as e:
        print(f"Error al procesar la imagen {filepath}: {e}")

# Convertir las imágenes a formato numpy
X = np.array(images)

# Hacer predicciones con el modelo
predicted_classes = car_model.predict(X)

# Mostrar resultados y visualización
for i, pred in enumerate(predicted_classes):
    # Obtener la clase predicha
    pred_class_index = np.argmax(pred)
    pred_class = cars[pred_class_index]
    print(f"{filenames[i]} -> Predicción: {pred_class}")

    # Mostrar la imagen original con el texto de predicción
    img_color = cv.imread(filenames[i])
    if img_color is None:
        print(f"Error: no se pudo cargar la imagen {filenames[i]}")
    else:
        # Redimensionar para visualización (manteniendo proporción)
        h, w, _ = img_color.shape
        scale = 500 / max(h, w)
        new_size = (int(w * scale), int(h * scale))
        img_resized = cv.resize(img_color, new_size)

        # Dibujar la predicción en la imagen
        cv.putText(img_resized, f"El carro es: {pred_class}", (10, 30), cv.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2)

        # Mostrar la imagen con la predicción
        cv.imshow(f"Predicción para {filenames[i]}", img_resized)
        cv.waitKey(0)
        cv.destroyAllWindows()
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# C:\devs\IAProyects\Proyecto CNN\Imagenes prueba\hummer.jpg -> Predicción: Hummer

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import numpy as np

y_pred = np.argmax(car_model.predict(valid_X), axis=1)
y_true = np.argmax(valid_label, axis=1)

cm = confusion_matrix(y_true, y_pred)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=cars)
disp.plot(cmap='Blues', xticks_rotation='vertical')
# Out:
# 284/284 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step
